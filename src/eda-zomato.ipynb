# %% [markdown]
# # Topics

# %% [markdown]
# **finding restaurants with most branches in Chennai**

# %% [markdown]
# **finding best restaurants with it's details**

# %% [markdown]
# **finding cheap and best restaurants**

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('../include/Zomato Chennai Listing 2020.csv')

# %%
#WE WILL COUNT THE NUMBER OF TIMES A RESTAURANT'S NAME HAS BEEN REPEATED

df['count']=1
a=df.groupby(['Name of Restaurant']).count()['count']



#THEN WE WILL SORT IN DESCENDING ORDER AND SLICE THE TOP 5
b=a.sort_values(ascending=False)
most_branches=b[0:6]

most_branches
# Out:
# Name of Restaurant
# Amma Unavagam      78
# CK's Bakery        71
# Domino's Pizza     66
# Lassi Shop         58
# OYALO              51
# Cafe Coffee Day    51
# Name: count, dtype: int64

# %%
#THIS IS A GRAPHICAL REPRESENTATION  
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(5)
plt.plot(most_branches,color='orange',linewidth=3,marker="D",markerfacecolor='black',markersize=8)
plt.xlabel('Restaurant')
plt.ylabel('No of branches')
plt.title('Restaurants with most branches across city')
plt.grid(axis='y')

# %% [markdown]
# IN ORDER TO FIND BEST RESTAURANT I ADDED BOTH DINING AND
# DELIVERY RATING AND RATED IT OUT OF 10

# %%
# FIRST I REPLACED 'NONE' WITH 0 IN THE DF AND THEN CREATED A NEW COLUMN CALLED "total_rating"

df.loc[df['Dining Rating']=='None','Dining Rating']=0
df.loc[df['Delivery Rating']=='None','Delivery Rating']=0


df['total_rating']=df['Dining Rating'].astype(float)+df['Delivery Rating'].astype(float)


#SORTING IN DESCENDING ORDER AND PICKING UP THE TOP 5
s=df['total_rating'].sort_values(ascending=False )
e=s[0:6]

# %%
best_restaurants=df.iloc[e.index]['Name of Restaurant']

# %%
#BEST RESTAURANTS(RATING WISE)

best_restaurants.reset_index()
# Out:
#    index                  Name of Restaurant
# 0    163    Momo Sa-Khang by Kailash Kitchen
# 1    155                   The Sandwich Shop
# 2     62  Amadora Gourmet Ice Cream & Sorbet
# 3     57                      Brownie Heaven
# 4    184                Gossip Fusion Bistro
# 5    192                        Kabab Corner

# %% [markdown]
# ## DETAILS OF TOP RATED RESTAURANTS

# %%
#GETTING THE DETAILS OF TOP RATED RESTAURANTS WITH FOR LOOP

a=1
for i in e.index:
    print("")
    print("")
    print(a,')',df.iloc[i])
    a+=1
# Out:
# 1 ) Zomato URL               https://www.zomato.com/chennai/momo-sa-khang-b...
# Name of Restaurant                        Momo Sa-Khang by Kailash Kitchen
# Address                   2/247, Perinbavilas Complex, Opposite Chitra ...
# Location                                                       Choolaimedu
# Cuisine                                              ['Momos', ' Chinese']
# Top Dishes               ['Momos', ' Noodle', ' Chowmein', ' Fried Momo...
# Price for 2                                                          350.0
# Dining Rating                                                          4.8
# Dining Rating Count                                                   1658
# Delivery Rating                                                        4.5
# Delivery Rating Count                                                 2825
# Features                 ['Home Delivery', 'Free Parking', 'Indoor Seat...
# count                                                                    1
# total_rating                                                           9.3
# Name: 163, dtype: object
#
#
# 2 ) Zomato URL               https://www.zomato.com/chennai/the-sandwich-sh...
# Name of Restaurant                                       The Sandwich Shop
# Address                            1, Subba Street, West Mambalam, Chennai
# Location                                                     West Mambalam
# Cuisine                           ['Sandwich', ' Fast Food', ' Beverages']
# Top Dishes               ['Mocktails', ' Fries', ' Pizza Sandwich', ' T...
# Price for 2                                                          300.0
# Dining Rating                                                          4.9
# Dining Rating Count                                                    584
# Delivery Rating                                                        4.4
# Delivery Rating Count                                                  895
# Features                 ['Home Delivery', 'Vegetarian Only', 'Bulk Ord...
# count                                                                    1
# total_rating                                                           9.3
# Name: 155, dtype: object
#
#
# 3 ) Zomato URL               https://www.zomato.com/chennai/amadora-gourmet...
# Name of Restaurant                      Amadora Gourmet Ice Cream & Sorbet
# Address                   23, Wallace Garden, 3rd Street, Nungambakkam,...
# Location                                                      Nungambakkam
# Cuisine                                         ['Desserts', ' Ice Cream']
# Top Dishes               ['Sandwich', ' Gelato', ' Chocolate Icecreams'...
# Price for 2                                                          500.0
# Dining Rating                                                          4.8
# Dining Rating Count                                                   1516
# Delivery Rating                                                        4.5
# Delivery Rating Count                                                  361
# Features                 ['Home Delivery', 'Outdoor Seating', 'Desserts...
# count                                                                    1
# total_rating                                                           9.3
# Name: 62, dtype: object
#
#
# 4 ) Zomato URL               https://www.zomato.com/chennai/brownie-heaven-...
# Name of Restaurant                                          Brownie Heaven
# Address                   193, Peters Road, Opposite New College, Royap...
# Location                                                        Royapettah
# Cuisine                              ['Bakery', ' Desserts', ' Beverages']
# Top Dishes               ['Vanilla Ice Cream', ' Brownie Shake', ' Filt...
# Price for 2                                                          350.0
# Dining Rating                                                          4.9
# Dining Rating Count                                                    842
# Delivery Rating                                                        4.3
# Delivery Rating Count                                                 2270
# Features                 ['Home Delivery', 'Indoor Seating', 'Desserts ...
# count                                                                    1
# total_rating                                                           9.2
# Name: 57, dtype: object
#
#
# 5 ) Zomato URL               https://www.zomato.com/chennai/gossip-fusion-b...
# Name of Restaurant                                    Gossip Fusion Bistro
# Address                   New 141, Old 191, Opposite HP Fuel Station, E...
# Location                                                          Kanathur
# Cuisine                  ['Italian', ' Continental', ' Burger', ' Sandw...
# Top Dishes               ['Tender Coconut Mousse', ' Iced Tea', ' Pasta...
# Price for 2                                                         1500.0
# Dining Rating                                                          4.9
# Dining Rating Count                                                    996
# Delivery Rating                                                        4.3
# Delivery Rating Count                                                  500
# Features                 ['Breakfast', 'Home Delivery', 'Free Parking',...
# count                                                                    1
# total_rating                                                           9.2
# Name: 184, dtype: object
#
#
# 6 ) Zomato URL               https://www.zomato.com/chennai/kabab-corner-eg...
# Name of Restaurant                                            Kabab Corner
# Address                   12/1, Opposite Royal Enfield Showroom, Egmore...
# Location                                                            Egmore
# Cuisine                                    ['Kebab', ' Rolls', ' Mughlai']
# Top Dishes               ['Rolls', ' Beef Fry', ' Beef Steak', ' Chicke...
# Price for 2                                                          450.0
# Dining Rating                                                          4.9
# Dining Rating Count                                                   1053
# Delivery Rating                                                        4.3
# Delivery Rating Count                                                 2080
# Features                 ['Home Delivery', 'Indoor Seating', 'Catering ...
# count                                                                    1
# total_rating                                                           9.2
# Name: 192, dtype: object

# %% [markdown]
# # CHEAP AND BEST RESTAURANTS

# %%
#HERE I FILTERED THE RESTAURANTS BY TOP RATING AND CHEAP PRICE


k=df.groupby(['Name of Restaurant']).mean().sort_values('total_rating',ascending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1874, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873 try:
# -> 1874     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1875 except Exception as err:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/ops.py:849, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     847     preserve_dtype = True
# --> 849 result = self._aggregate_series_pure_python(obj, func)
#     851 if len(obj) == 0 and len(result) == 0 and isinstance(obj.dtype, ExtensionDtype):
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/ops.py:877, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     876 for i, group in enumerate(splitter):
# --> 877     res = func(group)
#     878     res = extract_result(res)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:2380, in GroupBy.mean.<locals>.<lambda>(x)
#    2377 else:
#    2378     result = self._cython_agg_general(
#    2379         "mean",
# -> 2380         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    2381         numeric_only=numeric_only,
#    2382     )
#    2383     return result.__finalize__(self.obj, method="groupby")
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:6225, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6217 @doc(make_doc("mean", ndim=1))
#    6218 def mean(
#    6219     self,
#    (...)
#    6223     **kwargs,
#    6224 ):
# -> 6225     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:11992, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11985 def mean(
#   11986     self,
#   11987     axis: Axis | None = 0,
#    (...)
#   11990     **kwargs,
#   11991 ) -> Series | float:
# > 11992     return self._stat_function(
#   11993         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11994     )
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/generic.py:11949, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11947 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11949 return self._reduce(
#   11950     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11951 )
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/series.py:6133, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6129     raise TypeError(
#    6130         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6131         "with non-numeric dtypes."
#    6132     )
# -> 6133 return op(delegate, skipna=skipna, **kwds)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/nanops.py:1693, in _ensure_numeric(x)
#    1691 if isinstance(x, str):
#    1692     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1693     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1694 try:
#
# TypeError: Could not convert string 'https://www.zomato.com/chennai/3-degree-cafe-perambur' to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       1 #HERE I FILTERED THE RESTAURANTS BY TOP RATING AND CHEAP PRICE
# ----> 4 k=df.groupby(['Name of Restaurant']).mean().sort_values('total_rating',ascending=False)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:2378, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2371     return self._numba_agg_general(
#    2372         grouped_mean,
#    2373         executor.float_dtype_mapping,
#    2374         engine_kwargs,
#    2375         min_periods=0,
#    2376     )
#    2377 else:
# -> 2378     result = self._cython_agg_general(
#    2379         "mean",
#    2380         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    2381         numeric_only=numeric_only,
#    2382     )
#    2383     return result.__finalize__(self.obj, method="groupby")
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1929, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1926     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1927     return result
# -> 1929 new_mgr = data.grouped_reduce(array_func)
#    1930 res = self._wrap_agged_manager(new_mgr)
#    1931 out = self._wrap_aggregated_output(res)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/managers.py:1428, in BlockManager.grouped_reduce(self, func)
#    1424 if blk.is_object:
#    1425     # split on object-dtype blocks bc some columns may raise
#    1426     #  while others do not.
#    1427     for sb in blk._split():
# -> 1428         applied = sb.apply(func)
#    1429         result_blocks = extend_blocks(applied, result_blocks)
#    1430 else:
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/internals/blocks.py:366, in Block.apply(self, func, **kwargs)
#     360 @final
#     361 def apply(self, func, **kwargs) -> list[Block]:
#     362     """
#     363     apply the function to my values; return a block if we are not
#     364     one
#     365     """
# --> 366     result = func(self.values, **kwargs)
#     368     result = maybe_coerce_values(result)
#     369     return self._split_op_result(result)
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1926, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1923 else:
#    1924     return result
# -> 1926 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1927 return result
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/groupby/groupby.py:1878, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1876     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1877     # preserve the kind of exception that raised
# -> 1878     raise type(err)(msg) from err
#    1880 if ser.dtype == object:
#    1881     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->mean,dtype->object]

# %%
#slicing timeee
price=k['Price for 2'][0:6]
rating=k['total_rating'][0:6]

#TOOK THE NAME
res_name=['Momo Sa-Khang by Kailash Kitchen','Fusilli Reasons','Kabab Corner','Amadora Gourmet Ice Cream & Sorbet','Soy Soi','Gossip Fusion Bistro']

price=price.sort_values()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 #slicing timeee
# ----> 2 price=k['Price for 2'][0:6]
#       3 rating=k['total_rating'][0:6]
#       5 #TOOK THE NAME
#
# NameError: name 'k' is not defined

# %% [markdown]
# # BAR CHART

# %%
plt.bar(res_name,rating)
plt.plot(range(9))
plt.ylim(9,9.35)
plt.text(0,rating[0],'₹ 350',ha='center',va='bottom')
plt.text(1,rating[1],'₹ 400',ha='center',va='bottom')
plt.text(2,rating[2],'₹ 450',ha='center',va='bottom')
plt.text(3,rating[3],'₹ 500',ha='center',va='bottom')
plt.text(4,rating[4],'₹ 1400',ha='center',va='bottom')
plt.text(5,rating[5],'₹ 1500',ha='center',va='bottom')


plt.xticks(rotation=270)
plt.show()
